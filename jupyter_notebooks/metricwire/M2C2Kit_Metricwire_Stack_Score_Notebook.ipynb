# %% [markdown]
# # ABOUT THIS NOTEBOOK
#
# This is a Jupyter notebook designed to simplify data extraction and data deduplication of M2C2kit data on the production servers.
#
# Below is code to (1) download, (2) deduplicate and (3) save the data as a CSV.
#
# Before you can begin using this Jupyter notebook, you will have to submit a username and create a password using the [authorization guide](https://github.com/m2c2-project/m2c2kit-integration-guides/blob/main/docs/authorization_guide.md) and submit an [Airtable form](https://airtable.com/app0JQhjqc5VNZMpZ/shr2FrUEAeaZV7RzF) to request data access. Our team would also need to communicate that you have been entered into the system before proceeding here. If this has been completed, please proceed. Your username, password, and study_id will be used in the designated field within this Jupyter notebook.
#
# ## How is Data Saved by M2C2Kit?
#
# Data from assessments are saved every trial. As a result, you can expect duplication when you query the raw data from our database.

# %% [markdown]
# ## Before You Start Your Study
#
# Before beginning your study, please ensure that the 'user_uid' values you are receiving the dataframes above match what you'd expect from either Qualtrics (whatever criteria used) or Metricwire (24 characters, alphanumeric).

# %% [markdown]
# # Getting Started
#
# To get started with this Jupyter notebook, you will need to either:
#
# - Install [Anaconda](https://www.anaconda.com/)
# - Install [Jupyter Lab](https://jupyter.org/install)
# - Install [Visual Studio Code with the Jupyter Notebook Extension](https://code.visualstudio.com/)
#
# Once you've configured your frameowrk of choice, you will then need to install the following Python libraries (`pandas`, `requests`) by running the cell below.
#
# Thereafter, navigate to the cell below the heading `Configure your data query` and modify the username to the one you were provided by the M2C2 Team. You will be prompted for your password each time you login.

# %%
! pip install requests
! pip install pandas
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 requests-2.32.3 urllib3-2.2.2
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Load libraries and custom functions

# %% [markdown]
# ### Note: DO NOT modify any of the functions below

# %%
import urllib.parse
import datetime
import requests
import pandas as pd
from getpass import getpass
import glob
import json

# %%
def read_json_file(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return data

def get_data_from_json_files(json_files):
    data = []
    for file in json_files:
        data.append(read_json_file(file))
    return data

def parse_metricwire_data(filepath = "data/unzipped/*/*/*.json"):
    # locate json files in the unzipped folder
    json_files = glob.glob(filepath)
    print(f"Ready to process {len(json_files)} JSON files exported from Metricwire.")

    # specify filename from current run time for filenames
    ts_fn = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

    # load all data into list of dictionaries
    data = get_data_from_json_files(json_files)

    # Elevate the data
    datao = []
    for i in range(len(data)):
        for j in range(len(data[i])):
            print(data[i][j])
            x = data[i][j]
            # Extract the identifiers
            identifiers = {k: v for k, v in x.items() if k != 'data'}
            identifiers_keys = set(identifiers.keys())
            for entry in x['data']:
                new_entry = {**identifiers, **entry}
                datao.append(new_entry)
    return datao

# %%
def summary_symbol_search(x, trials_expected=20):
    d = {}
    d["flag_is_invalid_n_trials"] = x["submissionSessionId"].count() != trials_expected
    d["n_trials"] = x["submissionSessionId"].count()
    d["n_trials_lure"] = (x["trial_type"] == "lure").sum()
    d["n_trials_responsetime_lt250ms"] = (x["response_time_duration_ms"] < 250).sum()
    d["n_trials_responsetime_gt10000ms"] = (
        x["response_time_duration_ms"] > 10000
    ).sum()
    d["n_correct_trials"] = (
        x["user_response_index"] == x["correct_response_index"]
    ).sum()
    d["n_incorrect_trials"] = (
        x["user_response_index"] != x["correct_response_index"]
    ).sum()
    d["mean_response_time_overall"] = x["response_time_duration_ms"].mean()
    d["mean_response_time_correct"] = x.loc[
        (x["user_response_index"] == x["correct_response_index"]),
        "response_time_duration_ms",
    ].mean()
    d["mean_response_time_incorrect"] = x.loc[
        (x["user_response_index"] != x["correct_response_index"]),
        "response_time_duration_ms",
    ].mean()
    d["median_response_time_overall"] = x["response_time_duration_ms"].median()
    d["median_response_time_correct"] = x.loc[
        (x["user_response_index"] == x["correct_response_index"]),
        "response_time_duration_ms",
    ].median()
    d["median_response_time_incorrect"] = x.loc[
        (x["user_response_index"] != x["correct_response_index"]),
        "response_time_duration_ms",
    ].median()
    d["sd_response_time_overall"] = x["response_time_duration_ms"].std()
    d["sd_response_time_correct"] = x.loc[
        (x["user_response_index"] == x["correct_response_index"]),
        "response_time_duration_ms",
    ].std()
    d["sd_response_time_incorrect"] = x.loc[
        (x["user_response_index"] != x["correct_response_index"]),
        "response_time_duration_ms",
    ].std()
    return pd.Series(
        d,
        index=[
            "flag_is_invalid_n_trials",
            # 'flag_is_potentially_invalid_rt',
            "n_trials",
            "n_trials_lure",
            "n_correct_trials",
            "n_incorrect_trials",
            "n_trials_responsetime_lt250ms",
            "n_trials_responsetime_gt10000ms",
            "mean_response_time_overall",
            "mean_response_time_correct",
            "mean_response_time_incorrect",
            "median_response_time_overall",
            "median_response_time_correct",
            "median_response_time_incorrect",
            "sd_response_time_overall",
            "sd_response_time_correct",
            "sd_response_time_incorrect",
        ],
    )


def summary_grid_memory(x, trials_expected=4):
    d = {}
    d["flag_is_invalid_n_trials"] = x["submissionSessionId"].count() != trials_expected
    d["n_trials"] = x["submissionSessionId"].count()
    d["n_perfect_trials"] = (x["number_of_correct_dots"] == 3.0).sum()
    d["mean_correct_dots"] = (x["number_of_correct_dots"]).mean()
    d["min_correct_dots"] = (x["number_of_correct_dots"]).min()
    d["sum_correct_dots"] = (x["number_of_correct_dots"]).sum()
    return pd.Series(
        d,
        index=[
            "flag_is_invalid_n_trials",
            "n_trials",
            "n_perfect_trials",
            "mean_correct_dots",
            "min_correct_dots",
            "sum_correct_dots",
        ],
    )

def summarise_m2c2kit_data(df = None, activity_name=None, group_by=["participant_id", "session_uuid", "session_id"], trials_expected = -999, ts_fn = None):
    if activity_name == "symbol-search" or activity_name == "symbolsearch" or activity_name == "symbol_search" or activity_name == "Symbol Search" or activity_name == "Symbol Match":
        activity_name_fn = activity_name.replace(" ", "_").lower()
        df_session_summary = df.groupby(group_by).apply(summary_symbol_search, trials_expected=trials_expected)
        df_session_summary.reset_index().to_csv(f"m2c2kit_scored_activity-{activity_name_fn}_{ts_fn}.csv", index=False)
        valid_scoring = True
    if activity_name == "grid-memory" or activity_name == "Dot Memory" or activity_name == "Grid Memory":
        activity_name_fn = activity_name.replace(" ", "_").lower()
        df_session_summary = df.groupby(group_by).apply(summary_grid_memory, trials_expected=trials_expected)
        valid_scoring = True

    if valid_scoring:
        df_session_summary.reset_index().to_csv(f"m2c2kit_scored_activity-{activity_name_fn}_{ts_fn}.csv", index=False)
        return df_session_summary
    else:
        print("Activity not supported yet. Please contact M2C2 for further coordination.")
        df_session_summary = None

# %% [markdown]
# ## Locate and Parse all JSON files across all unzipped ZIP files

# %% [markdown]
# Directory structure should look like the directory tree below.
# That is to say, a folder containing folders of zip files exported from the Metricwire interface at this URL: XXXX
#
# ```
#         ├── cognitivetask-22b32593-1cef-4ebe-af5a-8efcaa32a10a
#         │   ├── 668eaa8c596e9abfbecf30b8
#         │   │   └── 668eaa8c596e9abfbecf30b8-submissions.json
#         │   ├── 668f0537c7c70cfc82e8c1ef
#         │   │   └── 668f0537c7c70cfc82e8c1ef-submissions.json
#         │   └── usersDataCount.csv
#         ├── cognitivetask-a4b87a20-7931-452b-a7e2-e997c79eded5
#         │   ├── 668eaa8c596e9abfbecf30b8
#         │   │   └── 668eaa8c596e9abfbecf30b8-submissions.json
#         │   ├── 668f0537c7c70cfc82e8c1ef
#         │   │   └── 668f0537c7c70cfc82e8c1ef-submissions.json
#         │   └── usersDataCount.csv
#         └── cognitivetask-fd457b1b-3a6a-437b-9b4b-847e969626ae
#             ├── 668eaa8c596e9abfbecf30b8
#             │   └── 668eaa8c596e9abfbecf30b8-submissions.json
#             ├── 668f0537c7c70cfc82e8c1ef
#             │   └── 668f0537c7c70cfc82e8c1ef-submissions.json
#             └── usersDataCount.csv
# ```

# %%
# filter `elevated_data` where activityName == 'Symbol Search'
data = parse_metricwire_data(filepath = "data/unzipped/*/*/*.json")
# Out:
# Ready to process 6 JSON files exported from Metricwire.
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed63c16e2fa2c407452da', 'userId': '668eaa8c596e9abfbecf30b8', 'activityId': '2bbb883d-28da-4294-90f7-61106a104ac7', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': '22c12aa2-b61e-4d30-8348-3461f286c242', 'triggerId': '668ed87e16e2fa2c4074677b', 'triggerTimestamp': '1720637643961', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668eaa8d596e9abfbecf30c3', 'activityName': 'Grid Memory', 'timeZoneMinutes': -300, 'sessionId': '9436abfe-a6f6-4aa0-b81e-f6d04c6c762c', 'date': '07/10/2024', 'time': '13:54:52', 'timestamp': 1720637692784, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-10T18:54:35.347Z', 'trial_begin_iso8601_timestamp': '2024-07-10T18:54:38.809Z', 'trial_end_iso8601_timestamp': '2024-07-10T18:54:53.102Z', 'trial_index': 0, 'response_time_duration_ms': 1745.5, 'presented_cells': [{'row': 0, 'column': 3}, {'row': 2, 'column': 4}, {'row': 3, 'column': 3}], 'selected_cells': [{'row': 4, 'column': 2}, {'row': 1
': 4, 'column': 3, 'tap_x': 29.182535807291668, 'tap_y': 35.9444580078125}}, {'elapsed_duration_ms': 7206.4000000003725, 'action_type': 'on-target', 'cell': {'row': 3, 'column': 2, 'tap_x': 48.03969319661458, 'tap_y': 21.658732096354168}}, {'elapsed_duration_ms': 7602.200000001118, 'action_type': 'on-target', 'cell': {'row': 4, 'column': 2, 'tap_x': 36.9920654296875, 'tap_y': 22.611124674479168}}, {'elapsed_duration_ms': 8266.200000001118, 'action_type': 'on-target', 'cell': {'row': 7, 'column': 4, 'tap_x': 36.23016357421875, 'tap_y': 10.611124674479168}}], 'number_of_correct_dots': 0, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:12:53.383Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:13:10.193Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:13:24.447Z', 'trial_index': 1, 'response_time_duration_ms': 1706, 'presented_cells': [{'row': 3, 'column': 2}, {'row': 1, 'column': 4}, {'row': 2, 'column': 1}], 'selected_cells': [{'row': 4, 'column': 2}, {'row': 1, 'column': 1}, {'row': 2, 'column': 4}], 'user_dot_actions': [{'elapsed_duration_ms': 707.0999999996275, 'action_type': 'placed', 'cell': {'row': 4, 'column': 2, 'tap_x': 22.896830240885414, 'tap_y': 3.46826171875}}, {'elapsed_duration_ms': 804.0999999996275,  ...
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed63c16e2fa2c407452da', 'userId': '668f0537c7c70cfc82e8c1ef', 'activityId': '6005e9e1-db2f-4662-9942-a5ff02ff0bd7', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': '7a695355-4740-40ea-972d-d1b0379264dd', 'triggerId': '668c418850f86a98b069ba82', 'triggerTimestamp': '1720710936506', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668f0538d9adbf0ad48e5704', 'activityName': 'Grid Memory', 'timeZoneMinutes': -300, 'sessionId': '0e72ef88-84ac-4331-9d3f-63ea596a7ffe', 'date': '07/11/2024', 'time': '10:16:29', 'timestamp': 1720710989183, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-11T15:16:11.946Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:16:14.364Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:16:28.884Z', 'trial_index': 0, 'response_time_duration_ms': 1970.7000000011176, 'presented_cells': [{'row': 0, 'column': 1}, {'row': 0, 'column': 2}, {'row': 3, 'column': 3}], 'selected_cells': [{'row': 3, 'column': 1}, {'row': 1, 'column': 3}, {'row': 4, 'column': 3}], 'user_dot_actions': [{'elapsed_duration_ms': 656.6000000014901, 'action_type': 'placed', 'cell': {'row': 3, 'column': 1, 'tap_x': 37.56349690755208, 'tap_y': 35.277791341145836}}, {'elapsed_duration_ms': 867.6000000014901, 'action_type': 'placed', 'cell': {'row': 1, 'column': 3, 'tap_x': 39.087300618489586, 'tap_y': 46.32539876302083}}, {'elapsed_duration_ms': 1532.7000000011176, 'action_type': 'placed', 'cell': {'row': 4, 'column': 3, 'tap_x': 44.039693196614586, 'tap_y': 12.611124674479166}}, {'elapsed_duration_ms': 1970.7000000011176, 'action_type': 'done', 'cell': None}], 'user_interference_actions': [{'elapsed_du
timestamp': 1720714967314, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-11T16:22:23.599Z', 'trial_begin_iso8601_timestamp': '2024-07-11T16:22:32.884Z', 'trial_end_iso8601_timestamp': '2024-07-11T16:22:47.131Z', 'trial_index': 0, 'response_time_duration_ms': 1706.699999999255, 'presented_cells': [{'row': 4, 'column': 0}, {'row': 2, 'column': 1}, {'row': 1, 'column': 0}], 'selected_cells': [{'row': 4, 'column': 3}, {'row': 2, 'column': 1}, {'row': 2, 'column': 4}], 'user_dot_actions': [{'elapsed_duration_ms': 706.3999999985099, 'action_type': 'placed', 'cell': {'row': 4, 'column': 3, 'tap_x': 47.08730061848958, 'tap_y': 25.182535807291668}}, {'elapsed_duration_ms': 756, 'action_type': 'placed', 'cell': {'row': 2, 'column': 1, 'tap_x': 5.563496907552083, 'tap_y': 16.420694986979168}}, {'elapsed_duration_ms': 997.3999999985099, 'action_type': 'placed', 'cell': {'row': 2, 'column': 4, 'tap_x': 8.801656087239584, 'tap_y': 18.706339518229168}}, {'elapsed_duration_ms': 1706.699999999255, 'action_type': 'done', 'cell': None}], 'user_interference_actions': [{'elapsed_duration_ms': 1426, 'action_type': 'on-target', 'cell': {'row': 5, 'column': 1, 'tap_x': 29.944447835286457, 'tap_y': 23.9444580078125}}, {'elapsed_duration_ms': 1784.800000000745, 'action_type': 'on-target', 'cell': {'row': 4, 'column': 1, 'tap_x': 32.992085774739586, 'tap_y': 30.9920654296875}}, {'elapsed_duration_ms': 2120.699999999255, 'action_type': 'on-target', 'cell': {'row': 7, 'column': 3, 'tap_x': 39.46828206380208, 'tap_y': 22.801595052083332}}, {'elapsed_duration_ms': 2973.60000000149, 'action_type': 'on-target', 'cell': {'row': 1, 'column': 3, 'tap_x': 51.277811686197914, 'tap_y': 40.325398763020836}}, {'elapsed_duration_ms': 3781, 'action_type': 'on-target', 'cell': {'row': 1, 'column': 1, 'tap_x': 32.23016357421875, 'tap_y': 31.18255615234375}}, {'elapsed_duration_ms': 5698.699999999255, 'action_type': 'on-target', 'cell': {'row': 2, 'column': 0, 'tap_x': 33.18254089355469, 'tap_y': 21.46826171875}}, {'elapsed_duration_ms': 6111.60000000149, 'action_type': 'on-target', 'cell': {'row': 1, 'column': 2, 'tap_x': 33.18253580729167, 'tap_y': 30.801595052083332}}, {'elapsed_duration_ms': 6541.699999999255, 'action_type': 'on-target', 'cell': {'row': 1, 'column': 3, 'tap_x': 40.23016357421875, 'tap_y': 37.27779134114583}}, {'elapsed_duration_ms': 7040, 'action_type': 'on-target', 'cell': {'row': 0, 'column': 2, 'tap_x': 33.9444580078125, 'tap_y': 42.801595052083336}}, {'elapsed_duration_ms': 7823.300000000745, 'action_type': 'on-target', 'cell': {'row': 4, 'column': 4, 'tap_x': 48.03969319661458, 'tap_y': 46.61112467447917}}], 'number_of_correct_dots': 1, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11
z', 'trial_end_iso8601_timestamp': '2024-07-11T15:12:48.124Z', 'trial_index': 4, 'trial_type': 'lure', 'card_configuration': {'top_cards_symbols': [{'top': 15, 'bottom': 8}, {'top': 6, 'bottom': 12}, {'top': 7, 'bottom': 13}], 'bottom_cards_symbols': [{'top': 15, 'bottom': 8}, {'top': 13, 'bottom': 14}]}, 'response_time_duration_ms': 46.29999999888241, 'user_response_index': 0, 'correct_response_index': 0, 'quit_button_pressed': False}]}
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed6a116e2fa2c4074541c', 'userId': '668eaa8c596e9abfbecf30b8', 'activityId': '312db84b-72f8-4b07-9c91-84bbf8c90114', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': '22c12aa2-b61e-4d30-8348-3461f286c242', 'triggerId': '668ed87e16e2fa2c4074677b', 'triggerTimestamp': '1720637643961', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668eaa8d596e9abfbecf30c3', 'activityName': 'Color Shapes', 'timeZoneMinutes': -300, 'sessionId': '195129f0-4f9e-42e0-9fa7-cc7337399c27', 'date': '07/10/2024', 'time': '13:55:49', 'timestamp': 1720637749147, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-10T18:55:43.060Z', 'trial_begin_iso8601_timestamp': '2024-07-10T18:55:45.442Z', 'trial_end_iso8601_timestamp': '2024-07-10T18:55:49.515Z', 'trial_index': 0, 'present_shapes': [{'shape_index': 6, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 3, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 7, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 1}}], 'response_shapes': [{'shape_index': 6, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 1, 'column': 2}}, {'shape_index': 3, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 7, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 0, 'column': 0}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 555.2000000476837, 'user_response': 'same', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-10T18:55:43.060Z', 'trial_begin_iso8601_timestamp': '2024-07-10T18:55:49.522Z', 'trial_end_iso8601_timestamp': '2024-07-10T18:55:53.704Z', 'trial_index': 1, 'present_shapes': [{'shape_index': 6, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 0, 'column': 0}}, {'shape_index': 5, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 2}}, {'shape_index': 4, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 2, 'column': 0}}], 'response_shapes': [{'shape_index': 6, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 5, 'color_name': 'orange', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 1, 'column': 1}}, {'shape_index': 4, 'color_name': 'green', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 2}}], 'number_of_different_shapes': 2, 'response_time_duration_ms': 661.8999998569489, 'user_response': 'same', 'user_response_correct': False, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-10T18:55:43.060Z', 'trial_begin_iso8601_timestamp': '2024-07-10T18:55:53.709Z', 'trial_end_iso8601_timestamp': '2024-07-10T18:55:57.682Z', 'trial_index': 2, 'present_shapes': [{'shape_index': 5, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 3, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 1, 'column': 0}}, {'shape_index': 1, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 1}}], 'response_shapes': [{'shape_index': 5, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 2, 'column': 2}}, {'shape_index': 3, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 1, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 1, 'column': 1}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 440.2999999523163, 'user_response': 'same', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-10T18:55:43.060Z', 'trial_begin_iso8601_timesta ...
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed6a116e2fa2c4074541c', 'userId': '668f0537c7c70cfc82e8c1ef', 'activityId': '4b998c56-217d-454c-b2c1-8e680aa8e42f', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': 'a0983373-1a88-427c-8c3d-454ee1ff6bdd', 'triggerId': '668ed87e16e2fa2c4074677b', 'triggerTimestamp': '1720710719391', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668f0538d9adbf0ad48e5704', 'activityName': 'Color Shapes', 'timeZoneMinutes': -300, 'sessionId': '1a9f0700-b62c-4914-9f60-a7a3eadcfca7', 'date': '07/11/2024', 'time': '10:14:59', 'timestamp': 1720710899200, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-11T15:13:59.880Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:14:32.995Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:14:58.879Z', 'trial_index': 0, 'present_shapes': [{'shape_index': 3, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 7, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 0, 'column': 2}}, {'shape_index': 0, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 2}}], 'response_shapes': [{'shape_index': 3, 'color_name': 'black', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 7, 'color_name': 'green', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 2}}, {'shape_index': 0, 'color_name': 'orange', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 1, 'column': 1}}], 'number_of_different_shapes': 3, 'response_time_duration_ms': 22362, 'user_response': 'different', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:13:59.880Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:14:58.883Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:15:03.502Z', 'trial_index': 1, 'present_shapes': [{'shape_index': 0, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 2}}, {'shape_index': 7, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 1, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 1, 'column': 1}}], 'response_shapes': [{'shape_index': 0, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 0}}, {'shape_index': 7, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 1, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 2}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 1097.699999999255, 'user_response': 'same', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:13:59.880Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:15:03.505Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:15:07.867Z', 'trial_index': 2, 'present_shapes': [{'shape_index': 2, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 1, 'column': 0}}, {'shape_index': 3, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 0, 'column': 0}}, {'shape_index': 5, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 1}}], 'response_shapes': [{'shape_index': 2, 'color_name': 'pink', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 2}}, {'shape_index': 3, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 0, 'column': 0}}, {'shape_index': 5, 'color_name': 'orange', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 1, 'column': 2}}], 'number_of_different_shapes': 2, 'response_time_duration_ms': 829.0999999996275, 'user_response': 'same', 'user_response_correct': False, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:13:59.880Z', 'trial_begin_iso8601_timestamp': '202 ...
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed6a116e2fa2c4074541c', 'userId': '668f0537c7c70cfc82e8c1ef', 'activityId': 'c239d8fc-7391-491a-9b39-580faa5e0fe8', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': '7a695355-4740-40ea-972d-d1b0379264dd', 'triggerId': '668c418850f86a98b069ba82', 'triggerTimestamp': '1720710936506', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668f0538d9adbf0ad48e5704', 'activityName': 'Color Shapes', 'timeZoneMinutes': -300, 'sessionId': 'caa740ef-05fe-4fe6-bdf0-27872983d353', 'date': '07/11/2024', 'time': '10:17:26', 'timestamp': 1720711046648, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-11T15:17:17.304Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:17:22.233Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:17:26.347Z', 'trial_index': 0, 'present_shapes': [{'shape_index': 4, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 0, 'column': 0}}, {'shape_index': 0, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 6, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 1}}], 'response_shapes': [{'shape_index': 4, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 0, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 2}}, {'shape_index': 6, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 0}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 581.4000000003725, 'user_response': 'different', 'user_response_correct': False, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:17:17.304Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:17:26.352Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:17:30.584Z', 'trial_index': 1, 'present_shapes': [{'shape_index': 3, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 5, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 1, 'column': 1}}, {'shape_index': 0, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 2, 'column': 2}}], 'response_shapes': [{'shape_index': 3, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 0, 'column': 2}}, {'shape_index': 5, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 0, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 1, 'column': 1}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 702.5, 'user_response': 'same', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:17:17.304Z', 'trial_begin_iso8601_timestamp': '2024-07-11T15:17:30.588Z', 'trial_end_iso8601_timestamp': '2024-07-11T15:17:35.253Z', 'trial_index': 2, 'present_shapes': [{'shape_index': 7, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 1, 'column': 0}}, {'shape_index': 0, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 3, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 0, 'column': 1}}], 'response_shapes': [{'shape_index': 7, 'color_name': 'yellow', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 1, 'column': 2}}, {'shape_index': 0, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 3, 'color_name': 'pink', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 2, 'column': 2}}], 'number_of_different_shapes': 2, 'response_time_duration_ms': 1146.699999999255, 'user_response': 'different', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T15:17:17.304Z', 'trial_begin_iso ...
# {'studyId': '6687f32ac2db9efff4d31c66', 'cognitiveTaskId': '668ed6a116e2fa2c4074541c', 'userId': '668f0537c7c70cfc82e8c1ef', 'activityId': 'dc8f47b5-95c9-41c5-8f1e-9430435d16ff', 'activityVersion': '0.8.12 (38470c49)', 'submissionSessionId': '763c8274-6b71-4ab6-a242-415e352277bd', 'triggerId': '668ed87e16e2fa2c4074677b', 'triggerTimestamp': '1720714892848', 'deviceOs': 'android', 'deviceVersion': '34', 'appVersion': '4.2.0', 'deviceId': '668f0538d9adbf0ad48e5704', 'activityName': 'Color Shapes', 'timeZoneMinutes': -300, 'sessionId': 'f40c8483-d9c0-4567-8b72-2a96a54ef72c', 'date': '07/11/2024', 'time': '11:23:41', 'timestamp': 1720715021090, 'data': [{'activity_begin_iso8601_timestamp': '2024-07-11T16:23:34.517Z', 'trial_begin_iso8601_timestamp': '2024-07-11T16:23:36.744Z', 'trial_end_iso8601_timestamp': '2024-07-11T16:23:40.941Z', 'trial_index': 0, 'present_shapes': [{'shape_index': 7, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 1, 'column': 0}}, {'shape_index': 0, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 0, 'column': 0}}, {'shape_index': 6, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 0, 'column': 2}}], 'response_shapes': [{'shape_index': 7, 'color_name': 'black', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 0, 'color_name': 'orange', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 1, 'column': 2}}, {'shape_index': 6, 'color_name': 'blue', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 2, 'column': 1}}], 'number_of_different_shapes': 3, 'response_time_duration_ms': 672.6999999992549, 'user_response': 'different', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T16:23:34.517Z', 'trial_begin_iso8601_timestamp': '2024-07-11T16:23:40.946Z', 'trial_end_iso8601_timestamp': '2024-07-11T16:23:44.769Z', 'trial_index': 1, 'present_shapes': [{'shape_index': 3, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 5, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 1, 'column': 1}}, {'shape_index': 6, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 0, 'column': 2}}], 'response_shapes': [{'shape_index': 3, 'color_name': 'green', 'rgba_color': [0, 158, 115, 1], 'location': {'row': 2, 'column': 1}}, {'shape_index': 5, 'color_name': 'blue', 'rgba_color': [0, 114, 178, 1], 'location': {'row': 1, 'column': 2}}, {'shape_index': 6, 'color_name': 'black', 'rgba_color': [0, 0, 0, 1], 'location': {'row': 0, 'column': 0}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 300.69999999925494, 'user_response': 'same', 'user_response_correct': True, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T16:23:34.517Z', 'trial_begin_iso8601_timestamp': '2024-07-11T16:23:44.773Z', 'trial_end_iso8601_timestamp': '2024-07-11T16:23:48.547Z', 'trial_index': 2, 'present_shapes': [{'shape_index': 3, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 0, 'column': 2}}, {'shape_index': 2, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 2, 'column': 0}}, {'shape_index': 4, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 1, 'column': 2}}], 'response_shapes': [{'shape_index': 3, 'color_name': 'pink', 'rgba_color': [204, 121, 167, 1], 'location': {'row': 0, 'column': 1}}, {'shape_index': 2, 'color_name': 'orange', 'rgba_color': [213, 94, 0, 1], 'location': {'row': 1, 'column': 1}}, {'shape_index': 4, 'color_name': 'yellow', 'rgba_color': [240, 228, 66, 1], 'location': {'row': 1, 'column': 0}}], 'number_of_different_shapes': 0, 'response_time_duration_ms': 246.59999999776483, 'user_response': 'different', 'user_response_correct': False, 'quit_button_pressed': False}, {'activity_begin_iso8601_timestamp': '2024-07-11T16:23:34.517Z', 'trial_begin_iso8601_times ...

# %%
# filter `data` where activityName == 'task of interest'
dict_symbolsearch = [x for x in data if x['activityName'] == 'Symbol Search']
dict_gridmemory = [x for x in data if x['activityName'] == 'Grid Memory']

# load data into pandas dataframes
df_symbolsearch = pd.DataFrame(dict_symbolsearch)
df_gridmemory = pd.DataFrame(dict_gridmemory)

# %% [markdown]
# ## Deduplicate Dataset
#
# As mentioned above, data duplication is expected since the M2C2kit assessments save all data every trial to minimize any data loss. Below is code for deduplicating this data:

# %%
df_symbolsearch_dedup = df_symbolsearch.drop_duplicates(subset=['cognitiveTaskId', 'submissionSessionId', 'trial_begin_iso8601_timestamp'])
df_gridmemory_dedup = df_gridmemory.drop_duplicates(subset=['cognitiveTaskId', 'submissionSessionId', 'trial_begin_iso8601_timestamp'])

# %%
# confirm deduplication
print(f"Symbol Search: {df_symbolsearch.shape} to {df_symbolsearch_dedup.shape}")
print(f"Grid Memory: {df_gridmemory.shape} to {df_gridmemory_dedup.shape}")
# Out:
# Symbol Search: (26, 28) to (26, 28)
# Grid Memory: (16, 29) to (16, 29)

# %% [markdown]
# ## Preview Data

# %%
# preview data
display(df_symbolsearch_dedup.head(3))
display(df_gridmemory_dedup.head(3))
# Out:
#                     studyId           cognitiveTaskId  \
# 0  6687f32ac2db9efff4d31c66  66880801c2db9efff4d5e093
# 1  6687f32ac2db9efff4d31c66  66880801c2db9efff4d5e093
# 2  6687f32ac2db9efff4d31c66  66880801c2db9efff4d5e093
#
#                      userId                            activityId  \
# 0  668eaa8c596e9abfbecf30b8  4fac0197-1172-4b2c-85db-3ecb5d3d0f35
# 1  668eaa8c596e9abfbecf30b8  4fac0197-1172-4b2c-85db-3ecb5d3d0f35
# 2  668eaa8c596e9abfbecf30b8  4fac0197-1172-4b2c-85db-3ecb5d3d0f35
#
#      activityVersion                   submissionSessionId  \
# 0  0.8.12 (38470c49)  d3259542-ef62-433a-991e-2ebd613cf20f
# 1  0.8.12 (38470c49)  d3259542-ef62-433a-991e-2ebd613cf20f
# 2  0.8.12 (38470c49)  d3259542-ef62-433a-991e-2ebd613cf20f
#
#                   triggerId triggerTimestamp deviceOs deviceVersion  ...  \
# 0  668c418850f86a98b069ba82    1720630890468  android            34  ...
# 1  668c418850f86a98b069ba82    1720630890468  android            34  ...
# 2  668c418850f86a98b069ba82    1720630890468  android            34  ...
#
#   activity_begin_iso8601_timestamp trial_begin_iso8601_timestamp  \
# 0         2024-07-10T17:02:17.255Z      2024-07-10T17:02:30.333Z
# 1         2024-07-10T17:02:17.255Z      2024-07-10T17:02:31.925Z
# 2         2024-07-10T17:02:17.255Z      2024-07-10T17:02:32.758Z
#
#   trial_end_iso8601_timestamp  trial_index trial_type  \
# 0    2024-07-10T17:02:31.414Z          0.0       lure
# 1    2024-07-10T17:02:32.249Z          1.0     normal
# 2    2024-07-10T17:02:33.008Z          2.0       lure
#
#                                   card_configuration  \
# 0  {'top_cards_symbols': [{'top': 13, 'bottom': 1...
# 1  {'top_cards_symbols': [{'top': 20, 'bottom': 1...
# 2  {'top_cards_symbols': [{'top': 6, 'bottom': 13...
#
#   response_time_duration_ms  user_response_index correct_response_index  \
# 0                    1080.3                  0.0                    1.0
# 1                     323.3                  1.0                    0.0
# 2                     249.1                  0.0                    1.0
#
#   quit_button_pressed
# 0               False
# 1               False
# 2               False
#
# [3 rows x 28 columns]
#                     studyId           cognitiveTaskId  \
# 0  6687f32ac2db9efff4d31c66  668ed63c16e2fa2c407452da
# 1  6687f32ac2db9efff4d31c66  668ed63c16e2fa2c407452da
# 2  6687f32ac2db9efff4d31c66  668ed63c16e2fa2c407452da
#
#                      userId                            activityId  \
# 0  668eaa8c596e9abfbecf30b8  2bbb883d-28da-4294-90f7-61106a104ac7
# 1  668eaa8c596e9abfbecf30b8  2bbb883d-28da-4294-90f7-61106a104ac7
# 2  668eaa8c596e9abfbecf30b8  2bbb883d-28da-4294-90f7-61106a104ac7
#
#      activityVersion                   submissionSessionId  \
# 0  0.8.12 (38470c49)  22c12aa2-b61e-4d30-8348-3461f286c242
# 1  0.8.12 (38470c49)  22c12aa2-b61e-4d30-8348-3461f286c242
# 2  0.8.12 (38470c49)  22c12aa2-b61e-4d30-8348-3461f286c242
#
#                   triggerId triggerTimestamp deviceOs deviceVersion  ...  \
# 0  668ed87e16e2fa2c4074677b    1720637643961  android            34  ...
# 1  668ed87e16e2fa2c4074677b    1720637643961  android            34  ...
# 2  668ed87e16e2fa2c4074677b    1720637643961  android            34  ...
#
#   trial_begin_iso8601_timestamp trial_end_iso8601_timestamp trial_index  \
# 0      2024-07-10T18:54:38.809Z    2024-07-10T18:54:53.102Z           0
# 1      2024-07-10T18:54:53.111Z    2024-07-10T18:55:07.593Z           1
# 2      2024-07-10T18:55:07.604Z    2024-07-10T18:55:23.483Z           2
#
#    response_time_duration_ms  \
# 0                     1745.5
# 1                     1937.0
# 2                     3337.9
#
#                                      presented_cells  \
# 0  [{'row': 0, 'column': 3}, {'row': 2, 'column':...
# 1  [{'row': 4, 'column': 0}, {'row': 2, 'column':...
# 2  [{'row': 1, 'column': 3}, {'row': 4, 'column':...
#
#                                       selected_cells  \
# 0  [{'row': 4, 'column': 2}, {'row': 1, 'column':...
# 1  [{'row': 2, 'column': 2}, {'row': 2, 'column':...
# 2  [{'row': 2, 'column': 0}, {'row': 1, 'column':...
#
#                                     user_dot_actions  \
# 0  [{'elapsed_duration_ms': 682.0999999046326, 'a...
# 1  [{'elapsed_duration_ms': 729.2999999523163, 'a...
# 2  [{'elapsed_duration_ms': 1495.9000000953674, '...
#
#                            user_interference_actions number_of_correct_dots  \
# 0  [{'elapsed_duration_ms': 1018.2999999523163, '...                      1
# 1  [{'elapsed_duration_ms': 1972.9000000953674, '...                      0
# 2                                                 []                      1
#
#   quit_button_pressed
# 0               False
# 1               False
# 2               False
#
# [3 rows x 29 columns]

# %% [markdown]
# ## Save Data

# %%
# (potentially) with duplicates (i.e., all downloaded data)
df_symbolsearch.to_csv(f"tidy/m2c2kit_raw_symbolsearch_{ts_fn}.csv")
df_gridmemory.to_csv(f"tidy/m2c2kit_raw_gridmemory_{ts_fn}.csv")

# without duplicates (i.e., deduplicated data)
df_symbolsearch_dedup.to_csv(f"tidy/m2c2kit_dedup_symbolsearch_{ts_fn}.csv")
df_gridmemory_dedup.to_csv(f"tidy/m2c2kit_dedup_gridmemory_{ts_fn}.csv")

# %% [markdown]
# # Ready to score your data?
#
# If you are ready to score your data, please contact us at [m2c2@psu.edu](mailto:m2c2@psu.edu)

# %%
# specify expected number of trials (based on study configuration)
trials_expected_symbolsearch = 20
trials_expected_gridmemory = 4

# %%
# note, this function writes files for you! 
df_symbolsearch_summary = summarise_m2c2kit_data(df = df_symbolsearch_dedup, activity_name="Symbol Search", group_by=["userId", "submissionSessionId"], trials_expected = -999, ts_fn = ts_fn)
df_gridmemory_summary = summarise_m2c2kit_data(df = df_gridmemory_dedup, activity_name="Grid Memory", group_by=["userId", "submissionSessionId"], trials_expected = -999, ts_fn = ts_fn)
# Out:
# /Users/nur375/Documents/GitHub/m2c2kit-integration-guides/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/nur375/Documents/GitHub/m2c2kit-integration-guides/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /var/folders/s5/cdfgl21s67g7kcj9ts4x8pnn4njnsy/T/ipykernel_20586/2955901429.py:90: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_session_summary = df.groupby(group_by).apply(summary_symbol_search, trials_expected=trials_expected)
# /var/folders/s5/cdfgl21s67g7kcj9ts4x8pnn4njnsy/T/ipykernel_20586/2955901429.py:95: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_session_summary = df.groupby(group_by).apply(summary_grid_memory, trials_expected=trials_expected)

# %%
df_symbolsearch_summary
# Out:
#                                                                flag_is_invalid_n_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                      True
#                          22c12aa2-b61e-4d30-8348-3461f286c242                      True
#                          d3259542-ef62-433a-991e-2ebd613cf20f                      True
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                      True
#                          7a695355-4740-40ea-972d-d1b0379264dd                      True
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                      True
#
#                                                                n_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b         5
#                          22c12aa2-b61e-4d30-8348-3461f286c242         1
#                          d3259542-ef62-433a-991e-2ebd613cf20f         5
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd         5
#                          7a695355-4740-40ea-972d-d1b0379264dd         5
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd         5
#
#                                                                n_trials_lure  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b              3
#                          22c12aa2-b61e-4d30-8348-3461f286c242              0
#                          d3259542-ef62-433a-991e-2ebd613cf20f              3
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd              3
#                          7a695355-4740-40ea-972d-d1b0379264dd              3
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd              3
#
#                                                                n_correct_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                 2
#                          22c12aa2-b61e-4d30-8348-3461f286c242                 0
#                          d3259542-ef62-433a-991e-2ebd613cf20f                 1
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                 4
#                          7a695355-4740-40ea-972d-d1b0379264dd                 4
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                 2
#
#                                                                n_incorrect_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                   3
#                          22c12aa2-b61e-4d30-8348-3461f286c242                   1
#                          d3259542-ef62-433a-991e-2ebd613cf20f                   4
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                   1
#                          7a695355-4740-40ea-972d-d1b0379264dd                   1
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                   3
#
#                                                                n_trials_responsetime_lt250ms  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                              4
#                          22c12aa2-b61e-4d30-8348-3461f286c242                              0
#                          d3259542-ef62-433a-991e-2ebd613cf20f                              3
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                              1
#                          7a695355-4740-40ea-972d-d1b0379264dd                              2
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                              3
#
#                                                                n_trials_responsetime_gt10000ms  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                                0
#                          22c12aa2-b61e-4d30-8348-3461f286c242                                0
#                          d3259542-ef62-433a-991e-2ebd613cf20f                                0
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                                0
#                          7a695355-4740-40ea-972d-d1b0379264dd                                0
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                                1
#
#                                                                mean_response_time_overall  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                      120.94
#                          22c12aa2-b61e-4d30-8348-3461f286c242                         NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                      421.40
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                     3810.42
#                          7a695355-4740-40ea-972d-d1b0379264dd                      926.04
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                     4029.64
#
#                                                                mean_response_time_correct  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                     186.800
#                          22c12aa2-b61e-4d30-8348-3461f286c242                         NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                     225.100
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                    3408.575
#                          7a695355-4740-40ea-972d-d1b0379264dd                    1153.450
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                      95.900
#
#                                                                mean_response_time_incorrect  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                     77.033333
#                          22c12aa2-b61e-4d30-8348-3461f286c242                           NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                    470.475000
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                   5417.800000
#                          7a695355-4740-40ea-972d-d1b0379264dd                     16.400000
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                   6652.133333
#
#                                                                median_response_time_overall  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                          64.5
#                          22c12aa2-b61e-4d30-8348-3461f286c242                           NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                         249.1
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                        3230.5
#                          7a695355-4740-40ea-972d-d1b0379264dd                         638.1
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                         166.6
#
#                                                                median_response_time_correct  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                         186.8
#                          22c12aa2-b61e-4d30-8348-3461f286c242                           NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                         225.1
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                        1776.4
#                          7a695355-4740-40ea-972d-d1b0379264dd                         822.5
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                          95.9
#
#                                                                median_response_time_incorrect  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                            54.5
#                          22c12aa2-b61e-4d30-8348-3461f286c242                             NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                           286.2
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                          5417.8
#                          7a695355-4740-40ea-972d-d1b0379264dd                            16.4
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                           547.7
#
#                                                                sd_response_time_overall  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                111.710666
#                          22c12aa2-b61e-4d30-8348-3461f286c242                       NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                370.450618
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd               4052.814573
#                          7a695355-4740-40ea-972d-d1b0379264dd               1096.534198
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd               8506.166360
#
#                                                                sd_response_time_correct  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                172.958319
#                          22c12aa2-b61e-4d30-8348-3461f286c242                       NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                       NaN
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd               4563.318814
#                          7a695355-4740-40ea-972d-d1b0379264dd               1121.790656
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                 70.144993
#
#                                                                sd_response_time_incorrect
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 224f578c-10d0-48b1-92b0-eb9d59f1408b                   52.650008
#                          22c12aa2-b61e-4d30-8348-3461f286c242                         NaN
#                          d3259542-ef62-433a-991e-2ebd613cf20f                  408.561512
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                         NaN
#                          7a695355-4740-40ea-972d-d1b0379264dd                         NaN
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                10904.895910

# %%
df_gridmemory_summary
# Out:
#                                                                flag_is_invalid_n_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242                      True
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                      True
#                          7a695355-4740-40ea-972d-d1b0379264dd                      True
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                      True
#
#                                                                n_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242         4
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd         4
#                          7a695355-4740-40ea-972d-d1b0379264dd         4
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd         4
#
#                                                                n_perfect_trials  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242                 0
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                 0
#                          7a695355-4740-40ea-972d-d1b0379264dd                 0
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                 0
#
#                                                                mean_correct_dots  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242               0.50
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd               0.75
#                          7a695355-4740-40ea-972d-d1b0379264dd               0.00
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd               0.25
#
#                                                                min_correct_dots  \
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242                 0
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                 0
#                          7a695355-4740-40ea-972d-d1b0379264dd                 0
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                 0
#
#                                                                sum_correct_dots
# userId                   submissionSessionId
# 668eaa8c596e9abfbecf30b8 22c12aa2-b61e-4d30-8348-3461f286c242                 2
# 668f0537c7c70cfc82e8c1ef 763c8274-6b71-4ab6-a242-415e352277bd                 3
#                          7a695355-4740-40ea-972d-d1b0379264dd                 0
#                          a0983373-1a88-427c-8c3d-454ee1ff6bdd                 1

# %% [markdown]
# # Coming soon - this code as a pip installable package
# <!-- pip install cookiecutter
# cookiecutter https://github.com/waynerv/cookiecutter-pypackage.git -->
